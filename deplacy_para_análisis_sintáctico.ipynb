# %% [markdown]
# # [deplacy](https://koichiyasuoka.github.io/deplacy/) para análisis sintáctico

# %% [markdown]
# ## con [Stanza](https://stanfordnlp.github.io/stanza)

# %%
# !pip install deplacy stanza
import stanza
nlp=stanza.Pipeline("es")
doc=nlp("La pluma es la lengua del alma.")
import deplacy
deplacy.render(doc)
deplacy.serve(doc,port=None)
# import graphviz
# graphviz.Source(deplacy.dot(doc))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deplacy
#   Downloading deplacy-2.0.2-py3-none-any.whl (22 kB)
# Collecting stanza
#   Downloading stanza-1.4.0-py3-none-any.whl (574 kB)
#      |████████████████████████████████| 574 kB 11.5 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stanza) (4.64.0)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza) (1.11.0+cu113)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from stanza) (1.15.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza) (3.17.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza) (1.21.6)
# Collecting transformers
#   Downloading transformers-4.19.2-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 41.9 MB/s
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 51.2 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.0->stanza) (4.2.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2022.5.18.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers->stanza) (21.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 4.8 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 41.8 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->stanza) (3.7.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->stanza) (2019.12.20)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 36.7 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers->stanza) (4.11.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers->stanza) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers->stanza) (3.8.0)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=28a2d9359c943442e91d38ba1511763a52eafad8c760190cc8f26695856f3acc
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers, emoji, stanza, deplacy
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed deplacy-2.0.2 emoji-1.7.0 huggingface-hub-0.7.0 pyyaml-6.0 stanza-1.4.0 tokenizers-0.12.1 transformers-4.19.2
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.4.0/models/tokenize/ancora.pt:   0%|      …
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.4.0/models/mwt/ancora.pt:   0%|          |…
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.4.0/models/pos/ancora.pt:   0%|          |…
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.4.0/models/lemma/ancora.pt:   0%|         …
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.4.0/models/depparse/ancora.pt:   0%|      …
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.4.0/models/ner/conll02.pt:   0%|          …
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.4.0/models/backward_charlm/newswiki.pt:   …
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.4.0/models/forward_charlm/newswiki.pt:   0…
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.4.0/models/pretrain/ancora.pt:   0%|      …
# 2022-05-25 01:32:54 INFO: Loading these models for language: es (Spanish):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ancora  |
# | mwt       | ancora  |
# | pos       | ancora  |
# | lemma     | ancora  |
# | depparse  | ancora  |
# | ner       | conll02 |
# =======================
#
# 2022-05-25 01:32:54 INFO: Use device: cpu
# 2022-05-25 01:32:54 INFO: Loading: tokenize
# 2022-05-25 01:32:54 INFO: Loading: mwt
# 2022-05-25 01:32:54 INFO: Loading: pos
# 2022-05-25 01:32:54 INFO: Loading: lemma
# 2022-05-25 01:32:54 INFO: Loading: depparse
# 2022-05-25 01:32:54 INFO: Loading: ner
# 2022-05-25 01:32:56 INFO: Done loading processors!
# La     DET   <╗             det
# pluma  NOUN  ═╝<════════╗   nsubj
# es     AUX   <════════╗ ║   cop
# la     DET   <══════╗ ║ ║   det
# lengua NOUN  ═════╗═╝═╝═╝═╗ root
# de     ADP   <══╗ ║       ║ case
# el     DET   <╗ ║ ║       ║ det
# alma   NOUN  ═╝═╝<╝       ║ nmod
# .      PUNCT <════════════╝ punct
#         <iframe
#             width="100%"
#             height="400"
#             src="https://koichiyasuoka.github.io/deplacy/deplacy/editor.html#1%09La%09el%09DET%09_%09Definite%3DDef%7CGender%3DFem%7CNumber%3DSing%7CPronType%3DArt%092%09det%09_%09start_char%3D0%7Cend_char%3D2%7Cner%3DO%0A2%09pluma%09pluma%09NOUN%09_%09Gender%3DFem%7CNumber%3DSing%095%09nsubj%09_%09start_char%3D3%7Cend_char%3D8%7Cner%3DO%0A3%09es%09ser%09AUX%09_%09Mood%3DInd%7CNumber%3DSing%7CPerson%3D3%7CTense%3DPres%7CVerbForm%3DFin%095%09cop%09_%09start_char%3D9%7Cend_char%3D11%7Cner%3DO%0A4%09la%09el%09DET%09_%09Definite%3DDef%7CGender%3DFem%7CNumber%3DSing%7CPronType%3DArt%095%09det%09_%09start_char%3D12%7Cend_char%3D14%7Cner%3DO%0A5%09lengua%09lengua%09NOUN%09_%09Gender%3DFem%7CNumber%3DSing%090%09root%09_%09start_char%3D15%7Cend_char%3D21%7Cner%3DO%0A6-7%09del%09_%09_%09_%09_%09_%09_%09_%09start_char%3D22%7Cend_char%3D25%7Cner%3DO%0A6%09de%09de%09ADP%09_%09_%098%09case%09_%09_%0A7%09el%09el%09DET%09_%09Definite%3DDef%7CGender%3DMasc%7CNumber%3DSing%7CPronType%3DArt%098%09det%09_%09_%0A8%09alma%09alma%09NOUN%09_%09Gender%3DFem%7CNumber%3DSing%095%09nmod%09_%09start_char%3D26%7Cend_char%3D30%7Cner%3DO%0A9%09.%09.%09PUNCT%09_%09PunctType%3DPeri%095%09punct%09_%09start_char%3D30%7Cend_char%3D31%7Cner%3DO%0A%0A"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## con [NLP-Cube](https://github.com/Adobe/NLP-Cube)

# %%
# !pip install deplacy nlpcube
from cube.api import Cube
nlp=Cube()
nlp.load("es")
doc=nlp("La pluma es la lengua del alma.")
import deplacy
deplacy.render(doc)
deplacy.serve(doc,port=None)
# import graphviz
# graphviz.Source(deplacy.dot(doc))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deplacy in /usr/local/lib/python3.7/dist-packages (2.0.2)
# Collecting nlpcube
#   Downloading nlpcube-0.3.1.1-py3-none-any.whl (179 kB)
#      |████████████████████████████████| 179 kB 26.6 MB/s
# Collecting xmltodict==0.11.0
#   Downloading xmltodict-0.11.0-py2.py3-none-any.whl (7.2 kB)
# Requirement already satisfied: nltk>=3.2.5 in /usr/local/lib/python3.7/dist-packages (from nlpcube) (3.2.5)
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (from nlpcube) (1.1.4)
# Collecting pytorch-lightning==1.2.10
#   Downloading pytorch_lightning-1.2.10-py3-none-any.whl (841 kB)
#      |████████████████████████████████| 841 kB 41.7 MB/s
# Requirement already satisfied: Cython>=0.28.1 in /usr/local/lib/python3.7/dist-packages (from nlpcube) (0.29.30)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from nlpcube) (2019.12.20)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from nlpcube) (1.11.0+cu113)
# Collecting configparser
#   Downloading configparser-5.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from nlpcube) (1.21.6)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from nlpcube) (1.4.1)
# Collecting fasttext==0.9.2
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      |████████████████████████████████| 68 kB 6.2 MB/s
# Collecting nose2==0.7.3
#   Downloading nose2-0.7.3.tar.gz (139 kB)
#      |████████████████████████████████| 139 kB 69.8 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 60.5 MB/s
# Collecting transformers==4.2.2
#   Downloading transformers-4.2.2-py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 51.1 MB/s
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from nlpcube) (0.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from nlpcube) (4.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nlpcube) (4.64.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from nlpcube) (2.23.0)
# Collecting pybind11>=2.2
#   Using cached pybind11-2.9.2-py2.py3-none-any.whl (213 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from fasttext==0.9.2->nlpcube) (57.4.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from nose2==0.7.3->nlpcube) (1.15.0)
# Collecting coverage>=4.4.1
#   Downloading coverage-6.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (208 kB)
#      |████████████████████████████████| 208 kB 77.5 MB/s
# Collecting fsspec[http]>=0.8.1
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 78.2 MB/s
# Collecting torchmetrics==0.2.0
#   Downloading torchmetrics-0.2.0-py3-none-any.whl (176 kB)
#      |████████████████████████████████| 176 kB 40.9 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.2.10->nlpcube) (21.3)
# Collecting future>=0.16.0
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 68.6 MB/s
# Requirement already satisfied: tensorboard!=2.5.0,>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.2.10->nlpcube) (2.8.0)
# Requirement already satisfied: PyYAML!=5.4.*,>=5.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.2.10->nlpcube) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.2.2->nlpcube) (3.7.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 48.9 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.2.2->nlpcube) (4.11.3)
# Collecting tokenizers==0.9.4
#   Downloading tokenizers-0.9.4-cp37-cp37m-manylinux2010_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 50.5 MB/s
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 47.2 MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->nlpcube) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->nlpcube) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->nlpcube) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->nlpcube) (2.10)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (3.17.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (1.46.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (3.3.7)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (1.8.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.2.2->nlpcube) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.2.2->nlpcube) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.2.10->nlpcube) (3.2.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]>=0.8.1->pytorch-lightning==1.2.10->nlpcube) (21.4.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]>=0.8.1->pytorch-lightning==1.2.10->nlpcube) (2.0.12)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.6 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 77.1 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 58.3 MB/s
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask->nlpcube) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask->nlpcube) (2.11.3)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from flask->nlpcube) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask->nlpcube) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytorch-lightning==1.2.10->nlpcube) (3.0.9)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.2.2->nlpcube) (1.1.0)
# Building wheels for collected packages: fasttext, nose2, future, sacremoses
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3146218 sha256=22f58bb916d1069e6418711e881032038403dde9d51d135cd6aa49305809bc60
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/bf/b020d2be95f7641801a6597a29c8f4f19e38f9c02a345bab9b
#   Building wheel for nose2 (setup.py) ... done
#   Created wheel for nose2: filename=nose2-0.7.3-py3-none-any.whl size=127563 sha256=b0158b96be9ca7c5733c146a16c2d8c69304ca50a723e19eaf169247dc7e611c
#   Stored in directory: /root/.cache/pip/wheels/ba/d8/64/d27abce9f7fa5cf5c10c826765030fe8e9a3ea0b882816c32a
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=0070360d92d0005f89ddf24243f8fee76bec4ced18b14d7c877a93b4f72b6344
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=3447db8079c1eef576b7a76dc6a6aa6c13d802a442c5f90b5344adbc22d1b243
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built fasttext nose2 future sacremoses
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, fsspec, aiohttp, torchmetrics, tokenizers, sacremoses, pybind11, future, coverage, xmltodict, transformers, sentencepiece, pytorch-lightning, nose2, fasttext, configparser, nlpcube
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.12.1
#     Uninstalling tokenizers-0.12.1:
#       Successfully uninstalled tokenizers-0.12.1
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Attempting uninstall: coverage
#     Found existing installation: coverage 3.7.1
#     Uninstalling coverage-3.7.1:
#       Successfully uninstalled coverage-3.7.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.19.2
#     Uninstalling transformers-4.19.2:
#       Successfully uninstalled transformers-4.19.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires coverage==3.7.1, but you have coverage 6.4 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# coveralls 0.5 requires coverage<3.999,>=3.6, but you have coverage 6.4 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 configparser-5.2.0 coverage-6.4 fasttext-0.9.2 frozenlist-1.3.0 fsspec-2022.5.0 future-0.18.2 multidict-6.0.2 nlpcube-0.3.1.1 nose2-0.7.3 pybind11-2.9.2 pytorch-lightning-1.2.10 sacremoses-0.0.53 sentencepiece-0.1.96 tokenizers-0.9.4 torchmetrics-0.2.0 transformers-4.2.2 xmltodict-0.11.0 yarl-1.7.2
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-c213440ea9c7> in <module>()
#       1 get_ipython().system('pip install deplacy nlpcube')
# ----> 2 from cube.api import Cube
#       3 nlp=Cube()
#       4 nlp.load("es")
#       5 doc=nlp("La pluma es la lengua del alma.")
#
# /usr/local/lib/python3.7/dist-packages/cube/__init__.py in <module>()
# ----> 1 from cube.api import _load
#       2 from cube.version import __version__
#       3
#       4 import logging
#       5 logger = logging.getLogger('cube')
#
# /usr/local/lib/python3.7/dist-packages/cube/api.py in <module>()
#      27 from cube.io_utils.encodings import Encodings
#      28 from cube.io_utils.config import CompoundConfig, TokenizerConfig, ParserConfig, LemmatizerConfig
# ---> 29 from cube.networks.compound import Compound
#      30 from cube.networks.parser import Parser
#      31 from cube.networks.tokenizer import Tokenizer
#
# /usr/local/lib/python3.7/dist-packages/cube/networks/compound.py in <module>()
#       5 import torch.nn as nn
#       6 import torch.nn.functional as F
# ----> 7 import pytorch_lightning as pl
#       8 import numpy as np
#       9 from torch.utils.data import DataLoader
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/__init__.py in <module>()
#      26 _PROJECT_ROOT = os.path.dirname(_PACKAGE_ROOT)
#      27
# ---> 28 from pytorch_lightning import metrics  # noqa: E402
#      29 from pytorch_lightning.callbacks import Callback  # noqa: E402
#      30 from pytorch_lightning.core import LightningDataModule, LightningModule  # noqa: E402
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/metrics/__init__.py in <module>()
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 14 from pytorch_lightning.metrics.classification import (  # noqa: F401
#      15     Accuracy,
#      16     AUC,
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/metrics/classification/__init__.py in <module>()
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 14 from pytorch_lightning.metrics.classification.accuracy import Accuracy  # noqa: F401
#      15 from pytorch_lightning.metrics.classification.auc import AUC  # noqa: F401
#      16 from pytorch_lightning.metrics.classification.auroc import AUROC  # noqa: F401
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/metrics/classification/accuracy.py in <module>()
#      16 import torch
#      17
# ---> 18 from pytorch_lightning.metrics.functional.accuracy import _accuracy_compute, _accuracy_update
#      19 from pytorch_lightning.metrics.metric import Metric
#      20
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/metrics/functional/__init__.py in <module>()
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 14 from pytorch_lightning.metrics.functional.accuracy import accuracy  # noqa: F401
#      15 from pytorch_lightning.metrics.functional.auc import auc  # noqa: F401
#      16 from pytorch_lightning.metrics.functional.auroc import auroc  # noqa: F401
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/metrics/functional/accuracy.py in <module>()
#      16 import torch
#      17
# ---> 18 from pytorch_lightning.metrics.classification.helpers import _input_format_classification, DataType
#      19
#      20
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/metrics/classification/helpers.py in <module>()
#      17 import torch
#      18
# ---> 19 from pytorch_lightning.metrics.utils import select_topk, to_onehot
#      20 from pytorch_lightning.utilities import LightningEnum
#      21
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/metrics/utils.py in <module>()
#      16 import torch
#      17
# ---> 18 from pytorch_lightning.utilities import rank_zero_warn
#      19
#      20 METRIC_EPS = 1e-6
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/__init__.py in <module>()
#      16 import numpy
#      17
# ---> 18 from pytorch_lightning.utilities.apply_func import move_data_to_device  # noqa: F401
#      19 from pytorch_lightning.utilities.distributed import (  # noqa: F401
#      20     AllGatherGrad,
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/apply_func.py in <module>()
#      27 if _TORCHTEXT_AVAILABLE:
#      28     if _compare_version("torchtext", operator.ge, "0.9.0"):
# ---> 29         from torchtext.legacy.data import Batch
#      30     else:
#      31         from torchtext.data import Batch
#
# ModuleNotFoundError: No module named 'torchtext.legacy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## con [spaCy](https://spacy.io/)

# %%
# !pip install deplacy spacy-transformers
# !python -m spacy download es_dep_news_trf
import spacy
nlp=spacy.load("es_dep_news_trf")
doc=nlp("La pluma es la lengua del alma.")
import deplacy
deplacy.render(doc)
deplacy.serve(doc,port=None)
# import graphviz
# graphviz.Source(deplacy.dot(doc))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deplacy in /usr/local/lib/python3.7/dist-packages (2.0.2)
# Collecting spacy-transformers
#   Downloading spacy_transformers-1.1.5-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 138 kB/s
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers) (1.11.0+cu113)
# Collecting spacy<4.0.0,>=3.1.3
#   Downloading spacy-3.3.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 33.0 MB/s
# Collecting spacy-alignments<1.0.0,>=0.7.2
#   Downloading spacy_alignments-0.8.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 52.7 MB/s
# Requirement already satisfied: transformers<4.18.0,>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers) (4.2.2)
# Collecting srsly<3.0.0,>=2.4.0
#   Downloading srsly-2.4.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (457 kB)
#      |████████████████████████████████| 457 kB 56.8 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (57.4.0)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 77.2 MB/s
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (3.0.6)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.2-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (4.64.0)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.7-py3-none-any.whl (17 kB)
# Collecting thinc<8.1.0,>=8.0.14
#   Downloading thinc-8.0.16-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (660 kB)
#      |████████████████████████████████| 660 kB 50.0 MB/s
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (2.0.6)
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Downloading spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (2.23.0)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 28.5 MB/s
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.5 MB/s
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (1.0.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (2.11.3)
# Collecting typing-extensions<4.0.0.0,>=3.7.4
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (21.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (1.21.6)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<4.0.0,>=3.1.3->spacy-transformers) (0.9.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<4.0.0,>=3.1.3->spacy-transformers) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (3.0.9)
# Collecting smart-open<6.0.0,>=5.0.0
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 6.7 MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (1.24.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers) (2019.12.20)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers) (0.0.53)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers) (4.11.3)
# Requirement already satisfied: tokenizers==0.9.4 in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers) (0.9.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers) (3.7.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<4.0.0,>=3.1.3->spacy-transformers) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<4.0.0,>=3.1.3->spacy-transformers) (2.0.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<4.18.0,>=3.4.0->spacy-transformers) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<4.18.0,>=3.4.0->spacy-transformers) (1.15.0)
# Installing collected packages: typing-extensions, catalogue, typer, srsly, smart-open, pydantic, thinc, spacy-loggers, spacy-legacy, pathy, langcodes, spacy-alignments, spacy, spacy-transformers
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.2.0
#     Uninstalling typing-extensions-4.2.0:
#       Successfully uninstalled typing-extensions-4.2.0
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 6.0.0
#     Uninstalling smart-open-6.0.0:
#       Successfully uninstalled smart-open-6.0.0
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0+zzzcolab20220506162203 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# Successfully installed catalogue-2.0.7 langcodes-3.3.0 pathy-0.6.1 pydantic-1.8.2 smart-open-5.2.1 spacy-3.3.0 spacy-alignments-0.8.5 spacy-legacy-3.0.9 spacy-loggers-1.0.2 spacy-transformers-1.1.5 srsly-2.4.3 thinc-8.0.16 typer-0.4.1 typing-extensions-3.10.0.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting es-dep-news-trf==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_dep_news_trf-3.3.0/es_dep_news_trf-3.3.0-py3-none-any.whl (410.2 MB)
#      |████████████████████████████████| 410.2 MB 11 kB/s
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in /usr/local/lib/python3.7/dist-packages (from es-dep-news-trf==3.3.0) (3.3.0)
# Requirement already satisfied: spacy-transformers<1.2.0,>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from es-dep-news-trf==3.3.0) (1.1.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (0.6.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (1.0.7)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (8.0.16)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (0.9.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2.4.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2.11.3)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (3.10.0.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (0.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (57.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (3.0.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (4.64.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (1.21.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (0.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (21.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2.10)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (1.11.0+cu113)
# Requirement already satisfied: transformers<4.18.0,>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (4.2.2)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (0.8.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (4.11.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (3.7.0)
# Requirement already satisfied: tokenizers==0.9.4 in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (0.9.4)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (0.0.53)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (2019.12.20)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->es-dep-news-trf==3.3.0) (2.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<4.18.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.3.0) (1.1.0)
# Installing collected packages: es-dep-news-trf
# Successfully installed es-dep-news-trf-3.3.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_dep_news_trf')
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#
# /usr/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'transformers.models.yolos.configuration_yolos'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-467f7b955bf6> in <module>()
#       2 get_ipython().system('python -m spacy download es_dep_news_trf')
#       3 import spacy
# ----> 4 nlp=spacy.load("es_dep_news_trf")
#       5 doc=nlp("La pluma es la lengua del alma.")
#       6 import deplacy
#
# /usr/local/lib/python3.7/dist-packages/spacy/__init__.py in load(name, vocab, disable, exclude, config)
#      50     """
#      51     return util.load_model(
# ---> 52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#      54
#
# /usr/local/lib/python3.7/dist-packages/spacy/util.py in load_model(name, vocab, disable, exclude, config)
#     418             return get_lang_class(name.replace("blank:", ""))()
#     419         if is_package(name):  # installed as package
# --> 420             return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     421         if Path(name).exists():  # path to model data directory
#     422             return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# /usr/local/lib/python3.7/dist-packages/spacy/util.py in load_model_from_package(name, vocab, disable, exclude, config)
#     451     """
#     452     cls = importlib.import_module(name)
# --> 453     return cls.load(vocab=vocab, disable=disable, exclude=exclude, config=config)  # type: ignore[attr-defined]
#     454
#     455
#
# /usr/local/lib/python3.7/dist-packages/es_dep_news_trf/__init__.py in load(**overrides)
#       8
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# /usr/local/lib/python3.7/dist-packages/spacy/util.py in load_model_from_init_py(init_file, vocab, disable, exclude, config)
#     623         disable=disable,
#     624         exclude=exclude,
# --> 625         config=config,
#     626     )
#     627
#
# /usr/local/lib/python3.7/dist-packages/spacy/util.py in load_model_from_path(model_path, meta, vocab, disable, exclude, config)
#     489         config, vocab=vocab, disable=disable, exclude=exclude, meta=meta
#     490     )
# --> 491     return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#     492
#     493
#
# /usr/local/lib/python3.7/dist-packages/spacy/language.py in from_disk(self, path, exclude, overrides)
#    2041             # Convert to list here in case exclude is (default) tuple
#    2042             exclude = list(exclude) + ["vocab"]
# -> 2043         util.from_disk(path, deserializers, exclude)  # type: ignore[arg-type]
#    2044         self._path = path  # type: ignore[assignment]
#    2045         self._link_components()
#
# /usr/local/lib/python3.7/dist-packages/spacy/util.py in from_disk(path, readers, exclude)
#    1301         # Split to support file names like meta.json
#    1302         if key.split(".")[0] not in exclude:
# -> 1303             reader(path / key)
#    1304     return path
#    1305
#
# /usr/local/lib/python3.7/dist-packages/spacy/language.py in <lambda>(p, proc)
#    2036                 continue
#    2037             deserializers[name] = lambda p, proc=proc: proc.from_disk(  # type: ignore[misc]
# -> 2038                 p, exclude=["vocab"]
#    2039             )
#    2040         if not (path / "vocab").exists() and "vocab" not in exclude:  # type: ignore[operator]
#
# /usr/local/lib/python3.7/dist-packages/spacy_transformers/pipeline_component.py in from_disk(self, path, exclude)
#     418             "model": load_model,
#     419         }
# --> 420         util.from_disk(path, deserialize, exclude)
#     421         return self
#
# /usr/local/lib/python3.7/dist-packages/spacy/util.py in from_disk(path, readers, exclude)
#    1301         # Split to support file names like meta.json
#    1302         if key.split(".")[0] not in exclude:
# -> 1303             reader(path / key)
#    1304     return path
#    1305
#
# /usr/local/lib/python3.7/dist-packages/spacy_transformers/pipeline_component.py in load_model(p)
#     392             try:
#     393                 with open(p, "rb") as mfile:
# --> 394                     self.model.from_bytes(mfile.read())
#     395             except AttributeError:
#     396                 raise ValueError(Errors.E149) from None
#
# /usr/local/lib/python3.7/dist-packages/thinc/model.py in from_bytes(self, bytes_data)
#     592         msg = srsly.msgpack_loads(bytes_data)
#     593         msg = convert_recursive(is_xp_array, self.ops.asarray, msg)
# --> 594         return self.from_dict(msg)
#     595
#     596     def from_disk(self, path: Union[Path, str]) -> "Model":
#
# /usr/local/lib/python3.7/dist-packages/thinc/model.py in from_dict(self, msg)
#     630                 node.set_param(param_name, value)
#     631             for i, shim_bytes in enumerate(msg["shims"][i]):
# --> 632                 node.shims[i].from_bytes(shim_bytes)
#     633         return self
#     634
#
# /usr/local/lib/python3.7/dist-packages/spacy_transformers/layers/hf_shim.py in from_bytes(self, bytes_data)
#      98                         vocab_file_contents = fileh.read()
#      99
# --> 100             transformer = AutoModel.from_config(config)
#     101             self._hfmodel = HFObjects(
#     102                 tokenizer,
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/auto/auto_factory.py in from_config(cls, config, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/auto/auto_factory.py in keys(self)
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/auto/auto_factory.py in <listcomp>(.0)
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/auto/auto_factory.py in _load_attr_from_module(self, model_type, attr)
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/auto/auto_factory.py in getattribute_from_module(module, attr)
#
# /usr/local/lib/python3.7/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#
# /usr/local/lib/python3.7/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#
# RuntimeError: Failed to import transformers.models.yolos.configuration_yolos because of the following error (look up to see its traceback):
# No module named 'transformers.models.yolos.configuration_yolos'

# %% [markdown]
# ## con [UDPipe 2](http://ufal.mff.cuni.cz/udpipe/2)

# %%
# !pip install deplacy
def nlp(t):
  import urllib.request,urllib.parse,json
  with urllib.request.urlopen("https://lindat.mff.cuni.cz/services/udpipe/api/process?model=es&tokenizer&tagger&parser&data="+urllib.parse.quote(t)) as r:
    return json.loads(r.read())["result"]
doc=nlp("La pluma es la lengua del alma.")
import deplacy
deplacy.render(doc)
deplacy.serve(doc,port=None)
# import graphviz
# graphviz.Source(deplacy.dot(doc))

# %% [markdown]
# ## con [spacy-udpipe](https://github.com/TakeLab/spacy-udpipe)

# %%
# !pip install deplacy spacy-udpipe
import spacy_udpipe
spacy_udpipe.download("es")
nlp=spacy_udpipe.load("es")
doc=nlp("La pluma es la lengua del alma.")
import deplacy
deplacy.render(doc)
deplacy.serve(doc,port=None)
# import graphviz
# graphviz.Source(deplacy.dot(doc))

# %% [markdown]
# ## con [Trankit](https://github.com/nlp-uoregon/trankit)

# %%
# !pip install deplacy trankit transformers
import trankit
nlp=trankit.Pipeline("spanish")
doc=nlp("La pluma es la lengua del alma.")
import deplacy
deplacy.render(doc)
deplacy.serve(doc,port=None)
# import graphviz
# graphviz.Source(deplacy.dot(doc))

# %% [markdown]
# ## con [Camphr-Udify](https://camphr.readthedocs.io/en/stable/notes/udify.html)

# %%
# !pip install deplacy camphr en-udify@https://github.com/PKSHATechnology-Research/camphr_models/releases/download/0.7.0/en_udify-0.7.tar.gz
import pkg_resources,imp
imp.reload(pkg_resources)
import spacy
from spacy.lang.es import Spanish
nlp=Spanish()
import spacy
nlp.pipeline.extend(spacy.load("en_udify").pipeline)
doc=nlp("La pluma es la lengua del alma.")
import deplacy
deplacy.render(doc)
deplacy.serve(doc,port=None)
# import graphviz
# graphviz.Source(deplacy.dot(doc))

# %% [markdown]
# ## con [spaCy-jPTDP](https://github.com/KoichiYasuoka/spaCy-jPTDP)

# %%
# !pip install deplacy spacy_jptdp
import spacy_jptdp
nlp=spacy_jptdp.load("es_ancora")
doc=nlp("La pluma es la lengua del alma.")
import deplacy
deplacy.render(doc)
deplacy.serve(doc,port=None)
# import graphviz
# graphviz.Source(deplacy.dot(doc))
